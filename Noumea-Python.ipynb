# %%
import numpy as np
import scipy as sp
import pandas as pd
import csv
import difflib

# %%
df = pd.DataFrame.from_csv('noumea-aug22.csv', header=0, sep=',', index_col=0)
df
# Out:
#       age      neighbourhood  lives_in_noumea months_lived_in_noumea  \
# id
# 1    26.0                pk6             True                  2 ans
# 2    30.0            Magenta             True                     30
# 3    32.0            Trianon             True                     22
# 4    28.0                NaN            False                    NaN
# 5    26.0   Baie des citrons             True                 26 ans
# 6    29.0            Magenta             True                      4
# 7    46.0             Tuband             True                     10
# 8    46.0             Tuband             True                     10
# 9    37.0            Trianon             True                  3 ans
# 10   29.0  faubourg Blanchot             True                      1
# 11   63.0            Trianon             True                     12
# 12   48.0                VDC             True                     14
# ...

# %%
import levenshtein as lv
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-38ad330846d1> in <module>()
# ----> 1 import levenshtein as lv
#
# ImportError: No module named 'levenshtein'

# %%
from levenshtein.py import levenshtein
campaigns = (
    "HAMSTER",
    "TWO WORDED",
    "FRIDAY",
)

def get_campaign(word):
  return min(campaigns, key=lambda x: levenshtein(word, x))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-26-a0b7b94d963c> in <module>()
# ----> 1 from levenshtein.py import levenshtein
#       2 campaigns = (
#       3     "HAMSTER",
#       4     "TWO WORDED",
#       5     "FRIDAY",
#
# ImportError: No module named 'levenshtein'
