# %%
install.packages('devtools', repos='http://cran.us.r-project.org')
install.packages('jsonlite', repos='http://cran.us.r-project.org')
install.packages('reshape2', repos='http://cran.us.r-project.org')
install.packages('data.table', repos='http://cran.us.r-project.org')
install.packages('WriteXLS', repos='http://cran.us.r-project.org')
install.packages('dplyr', repos='http://cran.us.r-project.org')
# Out:
# Installing package into ‘/home/claire/R/x86_64-pc-linux-gnu-library/3.4’
# (as ‘lib’ is unspecified)
# Installing package into ‘/home/claire/R/x86_64-pc-linux-gnu-library/3.4’
# (as ‘lib’ is unspecified)
# Installing package into ‘/home/claire/R/x86_64-pc-linux-gnu-library/3.4’
# (as ‘lib’ is unspecified)
# Installing package into ‘/home/claire/R/x86_64-pc-linux-gnu-library/3.4’
# (as ‘lib’ is unspecified)
# Installing package into ‘/home/claire/R/x86_64-pc-linux-gnu-library/3.4’
# (as ‘lib’ is unspecified)
# Installing package into ‘/home/claire/R/x86_64-pc-linux-gnu-library/3.4’
# (as ‘lib’ is unspecified)
# also installing the dependencies ‘bindr’, ‘assertthat’, ‘bindrcpp’, ‘glue’, ‘pkgconfig’, ‘BH’, ‘plogr’

# %%
require(devtools)
install_github('jbryer/likert')
require(jsonlite)
require(likert)
require(reshape2)
library(data.table)
# Out:
# Skipping install of 'likert' from a github remote, the SHA1 (54a6c003) has not changed since last install.
#   Use `force = TRUE` to force installation

# %%
d <- read.csv("python-noumea-sept13.csv", header = TRUE)
d
# Out:
#     X   participant_id email                                  age
# 1    3  29             jonathan.rebouillon@gmail.com           26
# 2    4  30             Olivia.kurt@gmail.com                   30
# 3    6  32             ornc44@gmail.com                        32
# 4    7  33             e.launay@live.fr                        28
# 5    8  34             haguet.megane@gmail.com                 26
# 6    9  35                                                     29
# 7   10  36             fgambarotto@yahoo.fr                    46
# 8   12  38             marie.brenon@lagoon.nc                  37
# 9   14  40             marie.c.22@hotmail.fr                   29
# 10  15  41             micalonc@gmail.com                      63
# 11  16  42             hregimbe@yahoo.fr                       48
# 12  17  43             boris.valin@gmail.com                   25
# 13  19  45             hnatrsnj@hotmail.com                    31
# ...

# %%
# who lives outside of noumea
sum(d$lives_in_noumea=="False")
# Out:
# [1] 64

# %%
# converts all columns from character to factor for likert analysis
d[sapply(d, is.character)] <- lapply(d[sapply(d, is.character)], 
                                       as.factor)
sapply(d, class)
# Out:
#                            X               participant_id
#                    "integer"                    "integer"
#                        email                          age
#                     "factor"                    "numeric"
#        enable_receive_emails              lives_in_noumea
#                     "factor"                     "factor"
#       months_lived_in_noumea                neighbourhood
#                     "factor"                     "factor"
#           question_body_q1.1          question_body_q1.10
#                     "factor"                     "factor"
#          question_body_q1.11           question_body_q1.2
#                     "factor"                     "factor"
#           question_body_q1.3           question_body_q1.4
#                     "factor"                     "factor"
#           question_body_q1.5           question_body_q1.6
#                     "factor"                     "factor"
# ...

# %%
library(dplyr)
newdata <- select(d, "text_q1.1", "text_q1.2", "text_q1.3", "text_q1.4", "text_q1.5", "text_q1.6", "text_q1.7", "text_q1.8", "text_q1.9", "text_q1.10", "text_q1.11")
newdata2 <- select(d, "text_q2.1", "text_q2.2", "text_q2.3", "text_q2.4", "text_q2.5", 
                          "text_q2.6", "text_q2.7", "text_q2.8", "text_q2.9", "text_q2.10", 
                          "text_q2.11", "text_q2.12", "text_q2.13", "text_q2.14")
newdata3 <- select(d, "text_q3.1", "text_q3.2", "text_q3.3", "text_q3.4", "text_q3.5", 
                          "text_q3.6", "text_q3.7", "text_q3.8", "text_q3.9", "text_q3.10")
newdata4 <- select(d, "text_q4.1", "text_q4.2", "text_q4.3", "text_q4.4", "text_q4.5", 
                          "text_q4.6", "text_q4.7", "text_q4.8", "text_q4.9", "text_q4.10", 
                          "text_q4.11", "text_q4.12", "text_q2.13")
newdata5 <- select(d, "text_q5.1", "text_q5.2", "text_q5.3", "text_q5.4", "text_q5.5", 
                          "text_q5.6", "text_q5.7", "text_q5.8", "text_q5.9")

# %%
newdata <- data.frame(apply(newdata, 2, as.factor))
newdata2 <- data.frame(apply(newdata2, 2, as.factor))
newdata3 <- data.frame(apply(newdata3, 2, as.factor))
newdata4 <- data.frame(apply(newdata4, 2, as.factor))
newdata5 <- data.frame(apply(newdata5, 2, as.factor))

# %%
sapply(newdata, class)
sapply(newdata, function(x) { length(levels(x)) } )
sapply(newdata2, class)
sapply(newdata2, function(x) { length(levels(x)) } )
sapply(newdata3, class)
sapply(newdata3, function(x) { length(levels(x)) } )
sapply(newdata4, class)
sapply(newdata4, function(x) { length(levels(x)) } )
sapply(newdata5, class)
sapply(newdata5, function(x) { length(levels(x)) } )
# Out:
#  text_q1.1  text_q1.2  text_q1.3  text_q1.4  text_q1.5  text_q1.6  text_q1.7
#   "factor"   "factor"   "factor"   "factor"   "factor"   "factor"   "factor"
#  text_q1.8  text_q1.9 text_q1.10 text_q1.11
#   "factor"   "factor"   "factor"   "factor"
#  text_q1.1  text_q1.2  text_q1.3  text_q1.4  text_q1.5  text_q1.6  text_q1.7
#          5          5          5          5          5          5          5
#  text_q1.8  text_q1.9 text_q1.10 text_q1.11
#          5          5          5          5
#  text_q2.1  text_q2.2  text_q2.3  text_q2.4  text_q2.5  text_q2.6  text_q2.7
#   "factor"   "factor"   "factor"   "factor"   "factor"   "factor"   "factor"
#  text_q2.8  text_q2.9 text_q2.10 text_q2.11 text_q2.12 text_q2.13 text_q2.14
#   "factor"   "factor"   "factor"   "factor"   "factor"   "factor"   "factor"
#  text_q2.1  text_q2.2  text_q2.3  text_q2.4  text_q2.5  text_q2.6  text_q2.7
#          5          5          5          5          5          5          5
# ...

# %%
# create a new likert analysis
lik <- likert(newdata5)
summary(lik)
# Out:
#   Item
# 1 Cité de la Création et de l'innovation (hôtel, espaces culturels/musées, commerces...)
# 9 Musée Maritime de Nouvelle-Calédonie avec son pavillon flottant
# 8 Terminal croisiéristes
# 3 École de danse avec auditorium
# 5 Parking en silo avec façades vertes
# 4 Residentiel avec commerce au rez-de-chaussée
# 7 Espaces à usage collectif
# 2 Usage mixte: Bureaux + Logements
# 6 Bureaux
#   low       neutral  high     mean     sd
# 1 10.691824 30.18868 59.11950 3.716981 1.0898562
# 9  7.547170 36.47799 55.97484 3.742138 1.0154257
# 8 10.691824 35.84906 53.45912 3.616352 1.0644751
# 3 14.150943 39.62264 46.22642 3.465409 1.0613953
# 5  9.119497 44.65409 46.22642 3.537736 1.0523328
# 4 21.383648 36.79245 41.82390 3.238994 1.1425751
# 7  8.176101 51.88679 39.93711 3.459119 0.9414543
# 2 27.358491 42.13836 30.50314 3.018868 1.1481528
# 6 21.383648 55.66038 22.95597 2.996855 1.0156455

# %%
library(data.table)
# setnames(newdata, old = c("text_q1.1", "text_q1.2", "text_q1.3", "text_q1.4", "text_q1.5", 
#                           "text_q1.6", "text_q1.7", "text_q1.8", "text_q1.9", "text_q1.10", "text_q1.11"),
#          new = c("Étages: espaces educatifs", "Bureaux co-working (bureaux partagés)", "Commerces",
#                           "Espace à usage pluriel", "Friche artistique-studios", 
#                           "Espace recherche scientifique", "Café", "Bureaux", "Espaces verts et jardins potagers", 
#                           "Bâtiments fermés au public pour réhabilitation", 
#                           "Maison du projet (accueil/ exposition)"))

# setnames(newdata2, old = c("text_q2.1", "text_q2.2", "text_q2.3", "text_q2.4", "text_q2.5", 
#                           "text_q2.6", "text_q2.7", "text_q2.8", "text_q2.9", "text_q2.10", 
#                           "text_q2.11", "text_q2.12", "text_q2.13", "text_q2.14"),
#          new = c("Jardinières mobiles", "Stands restauration rapide/stand glacier", "Espace camionnettes restauration - Food truck",
#                 "Aire de jeux pour enfants", "Parasols géants", "Espace skateboard", 
#                  "Mur végétal anti-bruit", "Surfaces peintes toiles géantes pour artistes",
#                 "Zones vertes créées par percement de l’asphalte et zones pique-nique", 
#                  "Espace marchés éphémères (parvis + tables)", "Jardins potagers dans jardinières mobiles", 
#                  "Treillis avec hamacs", "Mobilier urbain reconfigurable", "Nouvelle station Néobus"))

setnames(newdata3, old = c("text_q3.1", "text_q3.2", "text_q3.3", "text_q3.4", "text_q3.5", 
                          "text_q3.6", "text_q3.7", "text_q3.8", "text_q3.9", "text_q3.10"),
                 new = c("Voie Express #1 déplacée", "Voie Néobus retracée et réaménagée + Arrêts",
                         "Voie Karuia bus + Arrêts", "Voie bus Raï + Gare Routière",
                         "Voie petit train", "Voie cyclable + Vélib’", "Voie piétonne", "Connections piétonnes", 
                         "Passerelle végétalisée", "Parking en silo avec façades vertes"))

setnames(newdata4, old = c("text_q4.1", "text_q4.2", "text_q4.3", "text_q4.4", "text_q4.5", 
                          "text_q4.6", "text_q4.7", "text_q4.8", "text_q4.9", "text_q4.10", 
                          "text_q4.11", "text_q4.12", "text_q2.13"),
                new = c("Parc botanique","Zone village océanien (espace pédagogique, kiosques culinaires, galerie marchande)",
                        "Zone culturelle (projection, auditorium, sculptures)", "Zone sport urbains (parc parkour et skateboard, espace de danse hip-hop)",
                        "Jardins suspendus", "Quais flottants avec jardins", "Parc linéaire avec promenade", "Piscine sur terrasse",
                        "Parvis du terminal croisiéristes", "Place publique avec jets d’eau", "Espaces verts en cœur d’îlot", 
                        "Littoral aménagé avec places publiques", "Amphithéâtre flottant"))
                        
setnames(newdata5, old = c("text_q5.1", "text_q5.2", "text_q5.3", "text_q5.4", "text_q5.5", 
                          "text_q5.6", "text_q5.7", "text_q5.8", "text_q5.9"),
                 new = c("Cité de la Création et de l'innovation (hôtel, espaces culturels/musées, commerces...)",
                        "Usage mixte: Bureaux + Logements", "École de danse avec auditorium", "Residentiel avec commerce au rez-de-chaussée",
                        "Parking en silo avec façades vertes", "Bureaux", "Espaces à usage collectif", "Terminal croisiéristes",
                        "Musée Maritime de Nouvelle-Calédonie avec son pavillon flottant"))

# %%
svg(filename="q5likert.svg", 
    width=5, 
    height=10, 
    pointsize=12)
plot(lik, type = "density") + scale_x_discrete(limits=c("1","2","3","4","5"))  + 
  labs(x="évaluation") + theme(plot.title = element_text(family = "Lato", size=12, hjust=0)) + 
  theme(axis.title = element_text(family = "Lato", size=12)) + theme(axis.text.x = element_text(
                           size=11))
dev.off()
# Out:
# Scale for 'x' is already present. Adding another scale for 'x', which will
# replace the existing scale.
# png
#   2
